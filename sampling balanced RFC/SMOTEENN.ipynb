# %%
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.combine import SMOTEENN
from collections import Counter
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from sklearn import metrics
import pandas as pd

# %%
train_csv = '../../dataset/train_N10.csv'
test_csv = '../../dataset/test_N10.csv'

train = pd.read_csv(train_csv)
test = pd.read_csv(test_csv)

x_train = train.drop(columns = ['osm_id', 'class'])
y_train = train['class']

print(x_train.shape)
print(y_train.shape)

x_test = test.drop(columns = ['osm_id', 'class'])
y_test = test['class']

print(x_test.shape)
print(y_test.shape)

print('Original training dataset shape %s' % Counter(y_train))
# Out:
# (4481441, 22)
# (4481441,)
# (1920618, 22)
# (1920618,)
# Original training dataset shape Counter({0: 4480444, 1: 997})

# %%
print("sampling strategy = auto")

sme = SMOTEENN()

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = BalancedRandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy = auto
# Resampled dataset shape Counter({0: 4475857, 1: 4441448})
# Training started
# Making Predictions
# AUC Score:
# 0.5321456197370733
# Accuracy Score
# 0.9996480299570243
# Precision Score
# 0.08681672025723473
# Recall Score
# 0.06443914081145585
# f1 Score
# 0.07397260273972603
# f1.5 Score
# 0.0699900299102692
# f2 Score
# 0.06794162053346754

# %%
print("sampling strategy 0.2")

sme = SMOTEENN(sampling_strategy = 0.2)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = BalancedRandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 0.2
# Resampled dataset shape Counter({0: 4475837, 1: 883480})
# Training started
# Making Predictions
# AUC Score:
# 0.5357180207037039
# Accuracy Score
# 0.999634492647679
# Precision Score
# 0.08746355685131195
# Recall Score
# 0.07159904534606205
# f1 Score
# 0.07874015748031496
# f1.5 Score
# 0.0758312269103636
# f2 Score
# 0.07429420505200594

# %%
print("sampling strategy 0.4")

sme = SMOTEENN(sampling_strategy = 0.4)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = BalancedRandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 0.4
# Resampled dataset shape Counter({0: 4475804, 1: 1766234})
# Training started
# Making Predictions
# AUC Score:
# 0.5309489172488202
# Accuracy Score
# 0.9996407406366076
# Precision Score
# 0.0804953560371517
# Recall Score
# 0.06205250596658711
# f1 Score
# 0.07008086253369271
# f1.5 Score
# 0.06675883863322142
# f2 Score
# 0.06503251625812906

# %%
print("sampling strategy 0.6")

sme = SMOTEENN(sampling_strategy = 0.6)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = BalancedRandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 0.6
# Resampled dataset shape Counter({0: 4475877, 1: 2664789})
# Training started
# Making Predictions
# AUC Score:
# 0.5333347709246539
# Accuracy Score
# 0.9996402199708635
# Precision Score
# 0.08536585365853659
# Recall Score
# 0.06682577565632458
# f1 Score
# 0.07496653279785809
# f1.5 Score
# 0.07161125319693094
# f2 Score
# 0.06986027944111776

# %%
print("sampling strategy 0.8")

sme = SMOTEENN(sampling_strategy = 0.8)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = BalancedRandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 0.8
# Resampled dataset shape Counter({0: 4475800, 1: 3538783})
# Training started
# Making Predictions
# AUC Score:
# 0.5309528230939956
# Accuracy Score
# 0.9996485506227683
# Precision Score
# 0.08441558441558442
# Recall Score
# 0.06205250596658711
# f1 Score
# 0.07152682255845942
# f1.5 Score
# 0.06755946432140716
# f2 Score
# 0.0655241935483871

# %%
print("sampling strategy 1.0")

sme = SMOTEENN(sampling_strategy = 1.0)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = BalancedRandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 1.0
# Resampled dataset shape Counter({0: 4475873, 1: 4439882})
# Training started
# Making Predictions
# AUC Score:
# 0.5357206246004875
# Accuracy Score
# 0.9996396993051195
# Precision Score
# 0.09009009009009009
# Recall Score
# 0.07159904534606205
# f1 Score
# 0.07978723404255318
# f1.5 Score
# 0.07642563198118756
# f2 Score
# 0.0746640119462419
