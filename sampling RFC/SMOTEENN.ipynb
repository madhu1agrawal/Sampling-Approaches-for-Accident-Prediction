# %%
from sklearn.ensemble import RandomForestClassifier
from imblearn.combine import SMOTEENN
from collections import Counter
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from sklearn import metrics
import pandas as pd

# %%
train_csv = '../../dataset/train_N10.csv'
test_csv = '../../dataset/test_N10.csv'

train = pd.read_csv(train_csv)
test = pd.read_csv(test_csv)

x_train = train.drop(columns = ['osm_id', 'class'])
y_train = train['class']

print(x_train.shape)
print(y_train.shape)

x_test = test.drop(columns = ['osm_id', 'class'])
y_test = test['class']

print(x_test.shape)
print(y_test.shape)

print('Original training dataset shape %s' % Counter(y_train))
# Out:
# (4481441, 22)
# (4481441,)
# (1920618, 22)
# (1920618,)
# Original training dataset shape Counter({0: 4480444, 1: 997})

# %%
print("sampling strategy = auto")

sme = SMOTEENN()

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy = auto
# Resampled dataset shape Counter({0: 4475772, 1: 4434431})
# Training started
# Making Predictions
# AUC Score:
# 0.5333386767698294
# Accuracy Score
# 0.9996480299570243
# Precision Score
# 0.08945686900958466
# Recall Score
# 0.06682577565632458
# f1 Score
# 0.07650273224043715
# f1.5 Score
# 0.07246665339438582
# f2 Score
# 0.07038712921065862

# %%
print("sampling strategy 0.2")

sme = SMOTEENN(sampling_strategy = 0.2)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 0.2
# Resampled dataset shape Counter({0: 4475818, 1: 882733})
# Training started
# Making Predictions
# AUC Score:
# 0.532143276229968
# Accuracy Score
# 0.9996433439653278
# Precision Score
# 0.084375
# Recall Score
# 0.06443914081145585
# f1 Score
# 0.07307171853856563
# f1.5 Score
# 0.06949118986339341
# f2 Score
# 0.06763527054108216

# %%
print("sampling strategy 0.4")

sme = SMOTEENN(sampling_strategy = 0.4)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 0.4
# Resampled dataset shape Counter({0: 4475975, 1: 1774985})
# Training started
# Making Predictions
# AUC Score:
# 0.5309494380281768
# Accuracy Score
# 0.9996417819680957
# Precision Score
# 0.08099688473520249
# Recall Score
# 0.06205250596658711
# f1 Score
# 0.07027027027027026
# f1.5 Score
# 0.06686449060336301
# f2 Score
# 0.06509764646970455

# %%
print("sampling strategy 0.6")

sme = SMOTEENN(sampling_strategy = 0.6)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 0.6
# Resampled dataset shape Counter({0: 4475717, 1: 2663847})
# Training started
# Making Predictions
# AUC Score:
# 0.5345301714645151
# Accuracy Score
# 0.99964490596256
# Precision Score
# 0.09034267912772585
# Recall Score
# 0.06921241050119331
# f1 Score
# 0.07837837837837837
# f1.5 Score
# 0.07457962413452027
# f2 Score
# 0.07260891337005508

# %%
print("sampling strategy 0.8")

sme = SMOTEENN(sampling_strategy = 0.8)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 0.8
# Resampled dataset shape Counter({0: 4475754, 1: 3548645})
# Training started
# Making Predictions
# AUC Score:
# 0.5345306922438718
# Accuracy Score
# 0.9996459472940481
# Precision Score
# 0.09090909090909091
# Recall Score
# 0.06921241050119331
# f1 Score
# 0.07859078590785908
# f1.5 Score
# 0.074697840301169
# f2 Score
# 0.07268170426065163

# %%
print("sampling strategy 1.0")

sme = SMOTEENN(sampling_strategy = 1.0)

x_res, y_res = sme.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling strategy 1.0
# Resampled dataset shape Counter({0: 4475848, 1: 4441324})
# Training started
# Making Predictions
# AUC Score:
# 0.5345301714645151
# Accuracy Score
# 0.99964490596256
# Precision Score
# 0.09034267912772585
# Recall Score
# 0.06921241050119331
# f1 Score
# 0.07837837837837837
# f1.5 Score
# 0.07457962413452027
# f2 Score
# 0.07260891337005508
