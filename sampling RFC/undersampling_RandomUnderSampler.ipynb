# %%
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from collections import Counter
from sklearn import metrics
import pandas as pd

# %%
train_csv = '../../dataset/train_N10.csv'
test_csv = '../../dataset/test_N10.csv'

train = pd.read_csv(train_csv)
test = pd.read_csv(test_csv)

x_train = train.drop(columns = ['osm_id', 'class'])
y_train = train['class']

print(x_train.shape)
print(y_train.shape)

x_test = test.drop(columns = ['osm_id', 'class'])
y_test = test['class']

print(x_test.shape)
print(y_test.shape)

print('Original training dataset shape %s' % Counter(y_train))
# Out:
# (4481441, 22)
# (4481441,)
# (1920618, 22)
# (1920618,)
# Original training dataset shape Counter({0: 4480444, 1: 997})

# %%
print("Sampling Strategy = auto")

rus = RandomUnderSampler()

x_res, y_res = rus.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# Sampling Strategy = auto
# Resampled dataset shape Counter({0: 997, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.7287976371373035
# Accuracy Score
# 0.7010441430831118
# Precision Score
# 0.0005518850268543424
# Recall Score
# 0.7565632458233891
# f1 Score
# 0.0011029654810077697
# f1.5 Score
# 0.0017906872962881366
# f2 Score
# 0.002751396963221547

# %%
print("Sampling Strategy = 0.2")

rus = RandomUnderSampler(sampling_strategy=0.2)

x_res, y_res = rus.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# Sampling Strategy = 0.2
# Resampled dataset shape Counter({0: 4985, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.643872045675417
# Accuracy Score
# 0.9916495627969747
# Precision Score
# 0.007814961870548937
# Recall Score
# 0.29594272076372313
# f1 Score
# 0.015227803020999632
# f1.5 Score
# 0.023974181650530196
# f2 Score
# 0.03534173174485549

# %%
print("Sampling Strategy = 0.4")

rus = RandomUnderSampler(sampling_strategy=0.4)

x_res, y_res = rus.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# Sampling Strategy = 0.4
# Resampled dataset shape Counter({0: 2492, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.7132841502017105
# Accuracy Score
# 0.939596005035879
# Precision Score
# 0.0017585903691315667
# Recall Score
# 0.48687350835322196
# f1 Score
# 0.003504522379982993
# f1.5 Score
# 0.0056693438568212766
# f2 Score
# 0.008667720389537554

# %%
print("Sampling Strategy = 0.6")

rus = RandomUnderSampler(sampling_strategy=0.6)

x_res, y_res = rus.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# Sampling Strategy = 0.6
# Resampled dataset shape Counter({0: 1661, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.7346683784754554
# Accuracy Score
# 0.8535330815393795
# Precision Score
# 0.0009168313172520647
# Recall Score
# 0.6157517899761337
# f1 Score
# 0.0018309364388286265
# f1.5 Score
# 0.0029697526180131346
# f2 Score
# 0.004557015684612123

# %%
print("Sampling Strategy = 0.8")

rus = RandomUnderSampler(sampling_strategy=0.8)

x_res, y_res = rus.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# Sampling Strategy = 0.8
# Resampled dataset shape Counter({0: 1246, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.7300153715298163
# Accuracy Score
# 0.7750468859502514
# Precision Score
# 0.0006640382782204699
# Recall Score
# 0.684964200477327
# f1 Score
# 0.0013267903000996246
# f1.5 Score
# 0.002153427216064763
# f2 Score
# 0.0033073660920070057

# %%
print("Sampling Strategy = 1.0")

rus = RandomUnderSampler(sampling_strategy=1.0)

x_res, y_res = rus.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# Sampling Strategy = 1.0
# Resampled dataset shape Counter({0: 997, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.7300370615550051
# Accuracy Score
# 0.6892088900551802
# Precision Score
# 0.0005409134906838955
# Recall Score
# 0.7708830548926014
# f1 Score
# 0.0010810684169041615
# f1.5 Score
# 0.001755197772207181
# f2 Score
# 0.00269699773218395
