# %%
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import InstanceHardnessThreshold
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from collections import Counter
from sklearn import metrics
import pandas as pd

# %%
train_csv = '../../dataset/train_N10.csv'
test_csv = '../../dataset/test_N10.csv'

train = pd.read_csv(train_csv)
test = pd.read_csv(test_csv)

x_train = train.drop(columns = ['osm_id', 'class'])
y_train = train['class']

print(x_train.shape)
print(y_train.shape)

x_test = test.drop(columns = ['osm_id', 'class'])
y_test = test['class']

print(x_test.shape)
print(y_test.shape)

print('Original training dataset shape %s' % Counter(y_train))
# Out:
# (4481441, 22)
# (4481441,)
# (1920618, 22)
# (1920618,)
# Original training dataset shape Counter({0: 4480444, 1: 997})

# %%
print("sampling_strategy=auto")

iht = InstanceHardnessThreshold()

x_res, y_res = iht.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling_strategy=auto
# Resampled dataset shape Counter({0: 4456523, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.5749985475662607
# Accuracy Score
# 0.9994538216344947
# Precision Score
# 0.08333333333333333
# Recall Score
# 0.15035799522673032
# f1 Score
# 0.1072340425531915
# f1.5 Score
# 0.1205298013245033
# f2 Score
# 0.12952302631578946

# %%
print("sampling_strategy=0.2")

iht = InstanceHardnessThreshold(sampling_strategy=0.2)

x_res, y_res = iht.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling_strategy=0.2
# Resampled dataset shape Counter({0: 4456437, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.5785766771058152
# Accuracy Score
# 0.9994517389715185
# Precision Score
# 0.08616187989556136
# Recall Score
# 0.1575178997613365
# f1 Score
# 0.11139240506329115
# f1.5 Score
# 0.12553035844915875
# f2 Score
# 0.13513513513513511

# %%
print("sampling_strategy=0.4")

iht = InstanceHardnessThreshold(sampling_strategy=0.4)

x_res, y_res = iht.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling_strategy=0.4
# Resampled dataset shape Counter({0: 4456472, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.561881690337582
# Accuracy Score
# 0.99946735894384
# Precision Score
# 0.07344632768361582
# Recall Score
# 0.12410501193317422
# f1 Score
# 0.09228039041703637
# f1.5 Score
# 0.10237770710283205
# f2 Score
# 0.10906040268456377

# %%
print("sampling_strategy=0.6")

iht = InstanceHardnessThreshold(sampling_strategy=0.6)

x_res, y_res = iht.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling_strategy=0.6
# Resampled dataset shape Counter({0: 4456297, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.5654400302615811
# Accuracy Score
# 0.9994257056843162
# Precision Score
# 0.06926952141057935
# Recall Score
# 0.13126491646778043
# f1 Score
# 0.09068425391591098
# f1.5 Score
# 0.10292212465812582
# f2 Score
# 0.11133603238866396

# %%
print("sampling_strategy=0.8")

iht = InstanceHardnessThreshold(sampling_strategy=0.8)

x_res, y_res = iht.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling_strategy=0.8
# Resampled dataset shape Counter({0: 4456390, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.5595013048449939
# Accuracy Score
# 0.999478813590209
# Precision Score
# 0.07331378299120235
# Recall Score
# 0.11933174224343675
# f1 Score
# 0.09082652134423252
# f1.5 Score
# 0.10001538698261271
# f2 Score
# 0.10602205258693807

# %%
print("sampling_strategy=1.0")

iht = InstanceHardnessThreshold(sampling_strategy=1.0)

x_res, y_res = iht.fit_resample(x_train, y_train)

print('Resampled dataset shape %s' % Counter(y_res))

clf = RandomForestClassifier()

print("Training started")
clf.fit(x_res, y_res)

print("Making Predictions")
y_pred = clf.predict(x_test)

print("AUC Score:")
print(roc_auc_score(y_test, y_pred))

print("Accuracy Score")
print(accuracy_score(y_test, y_pred))

print("Precision Score")
print(precision_score(y_test, y_pred))

print("Recall Score")
print(recall_score(y_test, y_pred))

print("f1 Score")
print(f1_score(y_test, y_pred))

print("f1.5 Score")
print(fbeta_score(y_test, y_pred, beta=1.5, pos_label=1))

print("f2 Score")
print(fbeta_score(y_test, y_pred, beta=2, pos_label=1))
# Out:
# sampling_strategy=1.0
# Resampled dataset shape Counter({0: 4456443, 1: 997})
# Training started
# Making Predictions
# AUC Score:
# 0.5690460214967203
# Accuracy Score
# 0.999479334255953
# Precision Score
# 0.08321377331420372
# Recall Score
# 0.13842482100238662
# f1 Score
# 0.10394265232974911
# f1.5 Score
# 0.11495654825430704
# f2 Score
# 0.12220817530552043
